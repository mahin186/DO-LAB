# %%
<a href="https://colab.research.google.com/github/mahin186/DO-LAB/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Import neccessary libraries
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read the Excel file into a pandas Dataframe
# Replace 'path_to_file.xlsx' with the actual path to your file
file_path = '/content/drive/MyDrive/do folder 1/Session1_Exercise (1).xlsx'
df = pd.read_excel(file_path)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education test preparation course  \
# 0  female        group B           bachelor's degree                    none
# 1  female        group C                some college               completed
# 2  female        group B             master's degree                    none
# 3    male        group A          associate's degree                    none
# 4    male        group C                some college                    none
#
#           lunch  math score  reading score  writing score  Total  MAx  Min  \
# 0      standard          72             72             74    NaN  NaN  NaN
# 1      standard          69             90             88    NaN  NaN  NaN
# 2      standard          90             95             93    NaN  NaN  NaN
# 3  free/reduced          47             57             44    NaN  NaN  NaN
# 4      standard          76             78             75    NaN  NaN  NaN
#
#    Avg
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# sort the Dataframe by the 'Average' column in descending order
df_sorted = df.sort_values(by='Average ,ascending',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-d5b29072cace> in <cell line: 0>()
#       1 # sort the Dataframe by the 'Average' column in descending order
# ----> 2 df_sorted = df.sort_values(by='Average ,ascending',ascending=False)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
# ...
